# %% [markdown]
# ## Importando os módulos

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from linear_regression import *
from z_score import *

# %% [markdown]
# ## Preparando os dados

# %%
data = pd.read_csv('../artificial1d.csv', header=None)

X = data.iloc[:, :-1].values
y = (data.iloc[:, -1].values).reshape(-1, 1)

# %% [markdown]
# ### Normalizando

# %%
zs = ZScore()
X_norm = zs.fit_transform(X)

# %%
X = np.hstack((np.ones((X.shape[0], 1)), X))
X_norm = np.hstack((np.ones((X_norm.shape[0], 1)), X_norm))

# %% [markdown]
# ## Treinando o modelo

# %%
linreg = LinearRegression()
linreg.fit_gd(X_norm, y, num_epochs=500)

# %% [markdown]
# ## Resultados

# %% [markdown]
# ### MSE

# %%
mse = linreg.get_mse(X_norm, y)
print(f'MSE = {mse[0]}')
# Out:
# MSE = 0.21340090132936987

# %% [markdown]
# ### Parâmetros

# %%
w = linreg.get_params()
print(f'Parâmetros = \n{w}')
# Out:
# Parâmetros =
# [[0.06761792]
#  [0.95615043]]

# %% [markdown]
# ### Plot da curva

# %% [markdown]
# #### Plot

# %%
rng = np.arange(min(X[:, 1]), max(X[:, 1]), 0.1)
rng = rng.reshape(-1, 1)

rng_norm = zs.transform(rng)
rng_ones = np.hstack((np.ones((rng_norm.shape[0], 1)), rng_norm))

plt.title('Dados x Predição do modelo')
plt.scatter(X[:, 1], y)
plt.plot(rng, linreg.pred(rng_ones), c='orange')
plt.show()

# %%
rng = range(len(linreg.get_log()))

plt.title('Função de custo ao longo do tempo')
plt.plot(rng, linreg.get_log())
plt.show()
